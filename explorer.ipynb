# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils
from imp import reload
reload(utils)
import cv2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## distribution of steering angles

# %%
df = pd.read_csv('data/driving_log.csv')
df['steering'].plot(kind='hist',bins=20)

# %%
samples = utils.sample(df, 0.1, 1000)

# %%
samples.steering.plot(kind='hist',bins=20)

# %%
f,ax = plt.subplots(1,3,figsize=(24,16))
left= utils.read_image(samples.iloc[0]['left'])
center= utils.read_image(samples.iloc[0]['center'])
right= utils.read_image(samples.iloc[0]['right'])

ax[0].imshow(left)
ax[1].imshow(center)
ax[2].imshow(right)

# %%
f,ax = plt.subplots(1,3,figsize=(24,16))
ax[0].imshow(utils.flip_image(left, 10)[0])
ax[1].imshow(utils.flip_image(center,20)[0])
ax[2].imshow(utils.flip_image(right,-5)[0])

# %%
processed_center = utils.preprocess_image(center)
plt.imshow(processed_center)
