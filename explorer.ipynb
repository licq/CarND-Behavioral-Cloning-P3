# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils
from imp import reload
reload(utils)
import cv2

# %% [markdown]
# ## distribution of steering angles

# %%
df = pd.read_csv('data/driving_log.csv')
df['steering'].plot(kind='hist',bins=20)

# %%
samples = utils.sample(df, 0.1, 1000)

# %%
samples.steering.plot(kind='hist',bins=20)

# %%
f,ax = plt.subplots(1,3,figsize=(24,16))
left, center, right = utils.read_images(samples.iloc[0])
ax[0].imshow(left)
ax[1].imshow(center)
ax[2].imshow(right)

# %%
f,ax = plt.subplots(1,3,figsize=(24,16))
ax[0].imshow(utils.flip_image(left))
ax[1].imshow(utils.flip_image(center))
ax[2].imshow(utils.flip_image(right))

# %%
f,ax = plt.subplots(1,3,figsize=(24,16))
ax[0].imshow(utils.convert_gray(left),cmap='gray')
ax[1].imshow(utils.convert_gray(center),cmap='gray')
ax[2].imshow(utils.convert_gray(right),cmap='gray')
